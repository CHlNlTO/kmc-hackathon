# %%
import pandas as pd
import numpy as np
import cma  # Covariance Matrix Adaptation Evolution Strategy

# Load the dataset
jobs_df = pd.read_excel('jobs.xlsx')

# HR provides a dictionary with required skills and corresponding experience levels
hr_requirements = {
    'React': 5,        # 5+ years experience in React
    'Python': 2,       # 2+ years experience in Python
    'Tensorflow': 1,   # 1+ year experience in JavaScript
}

jobs_df.head()
# Out:
# c:\Users\Kraum\PROJECTS\Hackaton\venv\Lib\site-packages\cma\s.py:15: UserWarning: Could not import matplotlib.pyplot, therefore ``cma.plot()`` etc. is not available
#   _warnings.warn('Could not import matplotlib.pyplot, therefore'
#             Name      Skills  Years of Experience
# 0  Alice Johnson      Python                    5
# 1      Bob Smith      Python                    3
# 2  Charlie Brown      Python                    1
# 3   David Wilson  JavaScript                   10
# 4      Eva White  JavaScript                    2

# %%
def fitness_function(candidate_years_exp, skills, hr_requirements):
    experience_difference = 0
    for row, skill in enumerate(skills):
        required_exp = hr_requirements.get(skill, 0) 
        experience_difference += max(0, required_exp - candidate_years_exp[row])  
    return experience_difference

# %%
skills_list = list(hr_requirements.keys())  # List of skills HR wants
experience_data = []
candidate_names = []
for _, row in jobs_df.iterrows():
    candidate_skills = row['Skills'].split(", ") 
    candidate_experience = row['Years of Experience']
    
    # Check if the candidate has the required skills
    if all(skill in candidate_skills for skill in skills_list):
        candidate_experience_per_skill = [
            candidate_experience if skill in candidate_skills else 0 for skill in skills_list
        ]
        experience_data.append(candidate_experience_per_skill)
        candidate_names.append(row['Name'])

# %%
if len(experience_data) == 0 or len(candidate_names) == 0:
    print("No candidates found with the required skills.")
else:
    experience_data = np.array(experience_data)

    initial_guess = [5] * len(skills_list) 
    es = cma.CMAEvolutionStrategy(initial_guess, 0.5) 

    # Run the optimization process
    for _ in range(100):  
        solutions = es.ask()
        fitness_values = [fitness_function(solution, skills_list, hr_requirements) for solution in solutions]
        es.tell(solutions, fitness_values)

    # Get the best candidate from the optimization
    best_candidate_index = np.argmin(fitness_values)  
    best_candidate = experience_data[best_candidate_index]
    best_candidate_name = candidate_names[best_candidate_index]
    best_fitness = fitness_function(best_candidate, skills_list, hr_requirements)

    # Output the best match candidate's name, skills, experience level, and fitness score
    best_candidate_skills = {skills_list[i]: best_candidate[i] for i in range(len(skills_list))}
    print(f"Best candidate found: {best_candidate_name}")
    print("Skills and experience level:")
    for skill, exp in best_candidate_skills.items():
        print(f"{skill}: {exp:.2f} years")
    print(f"Fitness score (lower is better): {best_fitness:.2f}")
# Out:
# No candidates found with the required skills.

# %%
jobs_df
# Out:
#               Name      Skills  Years of Experience
# 0    Alice Johnson      Python                    5
# 1        Bob Smith      Python                    3
# 2    Charlie Brown      Python                    1
# 3     David Wilson  JavaScript                   10
# 4        Eva White  JavaScript                    2
# 5      Frank Black      Python                    8
# 6      Grace Green       React                    4
# 7       Henry Grey  TensorFlow                    6
# 8         Ian Blue       React                    7
# 9        Julia Red      Python                    5
# 10     Kyle Orange  JavaScript                    2
# 11      Laura Pink       React                    3
# 12     Mark Purple  JavaScript                    1
# 13      Nancy Cyan      Python                    4
# 14      Oscar Gold  JavaScript                    6
# 15     Paul Silver       React                    5
# 16    Quinn Bronze  JavaScript                    8
# 17  Rachel Magenta      Python                    2
# 18      Steve Teal  JavaScript                    7
# 19      Tina Coral      Python                    3
# 20    Uma Lavender  JavaScript                    1
# 21   Victor Indigo      Python                    9
# 22     Wendy Olive       React                    4
# 23     Xavier Teal  JavaScript                    2
# 24      Yara Peach      Python                    5
# 25    Zachary Mint  JavaScript                    6
# 26       Adam Plum       React                    3
# 27    Bella Cherry      Python                    4
# 28    Charlie Lime  JavaScript                    7
# 29     Diana Cocoa      Python                    1
# 30     Ethan Cream  JavaScript                   10
# 31    Fiona Walnut      Python                    5
# 32   George Walnut       React                    2
# 33    Holly Walnut  JavaScript                    6
# 34      Ian Walnut      Python                    8
# 35     Jane Walnut  JavaScript                    4
# 36    Kevin Walnut      Python                    1
# 37    Laura Walnut       React                    2
# 38      Max Walnut      Python                    5
# 39     Nina Walnut  JavaScript                    7
# 40   Oliver Walnut       React                    3
# 41      Pam Walnut      Python                    6
# 42    Quinn Walnut  JavaScript                    2
# 43     Rick Walnut      Python                    4
# 44      Sam Walnut       React                    5
# 45     Tina Walnut  JavaScript                   10
# 46      Uma Walnut      Python                    1
# 47    Vince Walnut       React                    8
# 48     Will Walnut      Python                    3

# %%
import pandas as pd
import numpy as np
import cma  # Covariance Matrix Adaptation Evolution Strategy

# Load the dataset
jobs_df = pd.read_excel('jobs.xlsx')

# HR provides a dictionary with required skills and corresponding experience levels
hr_requirements = {
    'React': 5,         # 5+ years experience in React
    'Python': 3,        # 3+ years experience in Python
    'JavaScript': 10,   # 10+ years experience in JavaScript
}

def fitness_function(candidate_years_exp, skills, hr_requirements):
    experience_difference = 0
    for row, skill in enumerate(skills):
        required_exp = hr_requirements.get(skill, 0)
        experience_difference += max(0, required_exp - candidate_years_exp[row])  
    return experience_difference

skills_list = list(hr_requirements.keys())  # List of skills HR wants
experience_data = []
candidate_names = []

# Populate experience_data and candidate_names
for _, row in jobs_df.iterrows():
    candidate_skills = row['Skills'].split(",")  # No space after comma
    candidate_experience = row['Years of Experience']
    
    # Debugging: Print candidate information
    # print(f"Candidate: {row['Name']}, Skills: {candidate_skills}, Experience: {candidate_experience}")

    # Create an experience vector for each candidate based on the skills list
    candidate_experience_per_skill = [
        candidate_experience if skill in candidate_skills else 0 for skill in skills_list
    ]
    
    # Check if the candidate has any of the required skills
    if any(skill in candidate_skills for skill in skills_list):
        experience_data.append(candidate_experience_per_skill)
        candidate_names.append(row['Name'])

if len(experience_data) == 0 or len(candidate_names) == 0:
    print("No candidates found with the required skills.")
else:
    experience_data = np.array(experience_data)

    # Initialize CMA-ES with an initial guess for experience levels
    initial_guess = np.zeros(len(skills_list))  # Starting point for optimization
    es = cma.CMAEvolutionStrategy(initial_guess, 0.5) 

    # Run the optimization process
    for _ in range(100):  # Run 100 iterations
        solutions = es.ask()
        fitness_values = [fitness_function(solution, skills_list, hr_requirements) for solution in solutions]
        es.tell(solutions, fitness_values)

    # Get the best candidate from the optimization
    best_candidate_index = np.argmin(fitness_values)  
    best_candidate = experience_data[best_candidate_index]
    best_candidate_name = candidate_names[best_candidate_index]
    best_fitness = fitness_function(best_candidate, skills_list, hr_requirements)

    # Prepare the ranking list of all candidates based on fitness scores
    fitness_scores = [fitness_function(exp, skills_list, hr_requirements) for exp in experience_data]
    ranked_candidates = sorted(zip(candidate_names, experience_data, fitness_scores), key=lambda x: x[2])

    # Output the ranked list
    print("Ranking of candidates:")
    for rank, (name, skills_exp, score) in enumerate(ranked_candidates, start=1):
        skills_output = ', '.join(f"{skills_list[i]}: {skills_exp[i]:.2f} years" for i in range(len(skills_list)))
        print(f"{rank}. {name} | {skills_output} | Fitness score: {score:.2f}")
# Out:
# (3_w,7)-aCMA-ES (mu_w=2.3,w_1=58%) in dimension 3 (seed=634238, Mon Oct 21 13:02:37 2024)
# Ranking of candidates:
# 1. David Wilson | React: 0.00 years, Python: 0.00 years, JavaScript: 10.00 years | Fitness score: 8.00
# 2. Ethan Cream | React: 0.00 years, Python: 0.00 years, JavaScript: 10.00 years | Fitness score: 8.00
# 3. Tina Walnut | React: 0.00 years, Python: 0.00 years, JavaScript: 10.00 years | Fitness score: 8.00
# 4. Quinn Bronze | React: 0.00 years, Python: 0.00 years, JavaScript: 8.00 years | Fitness score: 10.00
# 5. Steve Teal | React: 0.00 years, Python: 0.00 years, JavaScript: 7.00 years | Fitness score: 11.00
# 6. Charlie Lime | React: 0.00 years, Python: 0.00 years, JavaScript: 7.00 years | Fitness score: 11.00
# 7. Nina Walnut | React: 0.00 years, Python: 0.00 years, JavaScript: 7.00 years | Fitness score: 11.00
# 8. Oscar Gold | React: 0.00 years, Python: 0.00 years, JavaScript: 6.00 years | Fitness score: 12.00
# 9. Zachary Mint | React: 0.00 years, Python: 0.00 years, JavaScript: 6.00 years | Fitness score: 12.00
# 10. Holly Walnut | React: 0.00 years, Python: 0.00 years, JavaScript: 6.00 years | Fitness score: 12.00
# 11. Ian Blue | React: 7.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 13.00
# 12. Paul Silver | React: 5.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 13.00
# 13. Sam Walnut | React: 5.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 13.00
# 14. Vince Walnut | React: 8.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 13.00
# 15. Grace Green | React: 4.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 14.00
# 16. Wendy Olive | React: 4.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 14.00
# 17. Jane Walnut | React: 0.00 years, Python: 0.00 years, JavaScript: 4.00 years | Fitness score: 14.00
# 18. Alice Johnson | React: 0.00 years, Python: 5.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 19. Bob Smith | React: 0.00 years, Python: 3.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 20. Frank Black | React: 0.00 years, Python: 8.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 21. Julia Red | React: 0.00 years, Python: 5.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 22. Laura Pink | React: 3.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 23. Nancy Cyan | React: 0.00 years, Python: 4.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 24. Tina Coral | React: 0.00 years, Python: 3.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 25. Victor Indigo | React: 0.00 years, Python: 9.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 26. Yara Peach | React: 0.00 years, Python: 5.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 27. Adam Plum | React: 3.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 28. Bella Cherry | React: 0.00 years, Python: 4.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 29. Fiona Walnut | React: 0.00 years, Python: 5.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 30. Ian Walnut | React: 0.00 years, Python: 8.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 31. Max Walnut | React: 0.00 years, Python: 5.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 32. Oliver Walnut | React: 3.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 33. Pam Walnut | React: 0.00 years, Python: 6.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 34. Rick Walnut | React: 0.00 years, Python: 4.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 35. Will Walnut | React: 0.00 years, Python: 3.00 years, JavaScript: 0.00 years | Fitness score: 15.00
# 36. Eva White | React: 0.00 years, Python: 0.00 years, JavaScript: 2.00 years | Fitness score: 16.00
# 37. Kyle Orange | React: 0.00 years, Python: 0.00 years, JavaScript: 2.00 years | Fitness score: 16.00
# 38. Rachel Magenta | React: 0.00 years, Python: 2.00 years, JavaScript: 0.00 years | Fitness score: 16.00
# 39. Xavier Teal | React: 0.00 years, Python: 0.00 years, JavaScript: 2.00 years | Fitness score: 16.00
# 40. George Walnut | React: 2.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 16.00
# 41. Laura Walnut | React: 2.00 years, Python: 0.00 years, JavaScript: 0.00 years | Fitness score: 16.00
# 42. Quinn Walnut | React: 0.00 years, Python: 0.00 years, JavaScript: 2.00 years | Fitness score: 16.00
# 43. Charlie Brown | React: 0.00 years, Python: 1.00 years, JavaScript: 0.00 years | Fitness score: 17.00
# 44. Mark Purple | React: 0.00 years, Python: 0.00 years, JavaScript: 1.00 years | Fitness score: 17.00
# 45. Uma Lavender | React: 0.00 years, Python: 0.00 years, JavaScript: 1.00 years | Fitness score: 17.00
# 46. Diana Cocoa | React: 0.00 years, Python: 1.00 years, JavaScript: 0.00 years | Fitness score: 17.00
# 47. Kevin Walnut | React: 0.00 years, Python: 1.00 years, JavaScript: 0.00 years | Fitness score: 17.00
# 48. Uma Walnut | React: 0.00 years, Python: 1.00 years, JavaScript: 0.00 years | Fitness score: 17.00
